# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("/content/drive/MyDrive/datasets/coffee_shop_revenue.csv")
data.head()
# Out:
#    Number_of_Customers_Per_Day  Average_Order_Value  Operating_Hours_Per_Day  \
# 0                          152                 6.74                       14
# 1                          485                 4.50                       12
# 2                          398                 9.09                        6
# 3                          320                 8.48                       17
# 4                          156                 7.44                       17
#
#    Number_of_Employees  Marketing_Spend_Per_Day  Location_Foot_Traffic  \
# 0                    4                   106.62                     97
# 1                    8                    57.83                    744
# 2                    6                    91.76                    636
# 3                    4                   462.63                    770
# 4                    2                   412.52                    232
#
#    Daily_Revenue
# 0        1547.81
# 1        2084.68
# 2        3118.39
# ...

# %%
data.isna().sum()
# Out:
# Number_of_Customers_Per_Day    0
# Average_Order_Value            0
# Operating_Hours_Per_Day        0
# Number_of_Employees            0
# Marketing_Spend_Per_Day        0
# Location_Foot_Traffic          0
# Daily_Revenue                  0
# dtype: int64

# %%
x=data.iloc[:,:-1]
y=data.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
xtrainc=sc.fit_transform(xtrain)
xtestc=sc.fit_transform(xtest)

# %%
pd.DataFrame(xtrainc).head()
# Out:
#           0         1         2         3         4         5
# 0  0.598695 -1.036230  1.550939 -0.244482  0.218925  1.101653
# 1  0.536962 -0.843044  0.094145  0.564280  1.408468 -1.538784
# 2 -1.122115  1.162404 -0.779931 -0.514069 -1.417292 -0.935048
# 3  1.100277  0.527652 -0.779931 -1.592418  0.906976  1.028913
# 4  0.421213 -0.787849  0.094145 -0.514069  0.048299 -1.131444

# %%
from sklearn.ensemble import RandomForestRegressor
model=RandomForestRegressor()

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'n_estimators': [100, 200, 300],  # Number of trees
    'max_depth': [None, 10, 20],      # Depth of trees
    'min_samples_split': [2, 5, 10]   # Minimum samples to split a node
}

grid_search= GridSearchCV(estimator=model,param_grid=param_grid,cv=5,scoring='r2',n_jobs=-1,verbose=2)
grid_search.fit(xtrainc,ytrain)

best_model=grid_search.best_estimator_
best_model.fit(xtrainc,ytrain)

ypred=best_model.predict(xtestc)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits

# %%
"""model.fit(xtrainc,ytrain)
# Out:
# RandomForestRegressor()

# %%
"""ypred=model.predict(xtestc)

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
print(mean_absolute_error(ytest,ypred))
print(mean_squared_error(ytest,ypred))
print(r2_score(ytest,ypred))
# Out:
# 176.34948090491733
# 47784.008224291036
# 0.9488595750081706
